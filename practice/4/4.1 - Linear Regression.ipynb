# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# generation of synthetic dataset
N = 100
a = 1
b = 3

x = np.random.uniform(0, 5, N)
noise = np.random.normal(0, .5, N)
y = a * x + b + noise

plt.grid()
plt.scatter(x, y, marker = '.', color = 'r')

# %%
X = x.reshape(-1, 1)

# %%
x # 1d array
# Out:
# array([1.54060372, 3.82412892, 4.74403512, 1.5732504 , 3.31950591,
#        3.6142878 , 4.34713731, 2.90744595, 1.49607489, 0.10802801,
#        3.29192976, 1.11729312, 0.07808493, 2.4516353 , 3.50289966,
#        1.82540796, 2.78438541, 1.7874501 , 0.22044405, 4.25616141,
#        3.03623423, 4.94326967, 2.91823909, 2.41761477, 2.74740199,
#        2.14939168, 3.40380638, 2.23098243, 2.18304194, 2.21942388,
#        3.85723308, 0.24300964, 1.55575515, 1.06322237, 4.85969989,
#        2.14235265, 2.61439051, 2.80102239, 4.46359739, 4.69683124,
#        4.49414627, 2.01998387, 0.58281274, 3.9754201 , 1.00679736,
#        3.16763417, 2.68026581, 4.38932982, 0.7673427 , 3.92365404,
#        2.43993718, 4.75321906, 2.89609259, 2.92466327, 4.02127462,
#        3.81741126, 3.54164204, 1.02140418, 2.51645573, 1.34841426,
#        3.15869828, 2.06479208, 3.98149631, 2.44078301, 2.5526534 ,
#        2.76324692, 3.57569378, 0.52484219, 4.51140094, 0.21398444,
#        2.70059099, 2.75643336, 1.57460602, 4.27622534, 3.12539748,
#        3.81725187, 3.91159539, 2.98235464, 4.17674785, 4.27339295,
#        1.43823609, 4.11268586, 1.64919838, 1.46062438, 2.81300656,
#        3.31424171, 2.32106895, 4.6598963 , 2.66292679, 1.49067441,
#        2.45883311, 0.69181256, 2.99783759, 2.65754213, 2.43996768,
#        4.49516806, 2.2795014 , 1.60808844, 2.57695883, 0.40389586])

# %%
X # array where each row is an array to
# Out:
# array([[1.54060372],
#        [3.82412892],
#        [4.74403512],
#        [1.5732504 ],
#        [3.31950591],
#        [3.6142878 ],
#        [4.34713731],
#        [2.90744595],
#        [1.49607489],
#        [0.10802801],
#        [3.29192976],
#        [1.11729312],
#        [0.07808493],
#        [2.4516353 ],
#        [3.50289966],
#        [1.82540796],
#        [2.78438541],
#        [1.7874501 ],
#        [0.22044405],
#        [4.25616141],
#        [3.03623423],
#        [4.94326967],
#        [2.91823909],
#        [2.41761477],
#        [2.74740199],
#        [2.14939168],
#        [3.40380638],
#        [2.23098243],
#        [2.18304194],
#        [2.21942388],
#        [3.85723308],
#        [0.24300964],
#        [1.55575515],
#        [1.06322237],
#        [4.85969989],
#        [2.14235265],
#        [2.61439051],
#        [2.80102239],
#        [4.46359739],
#        [4.69683124],
#        [4.49414627],
#        [2.01998387],
#        [0.58281274],
#        [3.9754201 ],
#        [1.00679736],
#        [3.16763417],
#        [2.68026581],
#        [4.38932982],
#        [0.7673427 ],
#        [3.92365404],
#        [2.43993718],
#        [4.75321906],
#        [2.89609259],
#        [2.92466327],
#        [4.02127462],
#        [3.81741126],
#        [3.54164204],
#        [1.02140418],
#        [2.51645573],
#        [1.34841426],
#        [3.15869828],
#        [2.06479208],
#        [3.98149631],
#        [2.44078301],
#        [2.5526534 ],
#        [2.76324692],
#        [3.57569378],
#        [0.52484219],
#        [4.51140094],
#        [0.21398444],
#        [2.70059099],
#        [2.75643336],
#        [1.57460602],
#        [4.27622534],
#        [3.12539748],
#        [3.81725187],
#        [3.91159539],
#        [2.98235464],
#        [4.17674785],
#        [4.27339295],
#        [1.43823609],
#        [4.11268586],
#        [1.64919838],
#        [1.46062438],
#        [2.81300656],
#        [3.31424171],
#        [2.32106895],
#        [4.6598963 ],
#        [2.66292679],
#        [1.49067441],
#        [2.45883311],
#        [0.69181256],
#        [2.99783759],
#        [2.65754213],
#        [2.43996768],
#        [4.49516806],
#        [2.2795014 ],
#        [1.60808844],
#        [2.57695883],
#        [0.40389586]])

# %%
# a * x + b = y

model = LinearRegression()
model.fit(X, y)
model
# Out:
# LinearRegression()

# %%
a_found = model.coef_[0]
b_found = model.intercept_

# %%
a_found
# Out:
# np.float64(1.0280952297477823)

# %%
b_found
# Out:
# np.float64(2.859206832266787)
